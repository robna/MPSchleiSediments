# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
pd.options.plotting.backend = 'holoviews'

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import prepare_data
from components import PCOA
#from helpers import PipelineHelper, SMWrapper
from settings import Config, shortnames, target
from plots import scatter_chart
from geo import get_wwtp_influence

# %% [markdown]
# ## Data preparation

# %%
# %%capture
# cell magic to supress output. Comment it out to see output of this cell.

# What happened so far: DB extract and blank procedure. Now import resulting MP data from csv
mp_pdd = prepare_data.get_pdd()

# Also import sediment data (sediment frequencies per size bin from master sizer export)
grainsize_iow, grainsize_cau = prepare_data.get_grainsizes()[0:2]
scor_iow = PCOA(grainsize_iow, 2)[0]
scor_cau = PCOA(grainsize_cau, 2)[0]

# ...some data wrangling to prepare particle domain data and sample domain data for MP and combine with certain sediment aggregates.
sdd_iow = prepare_data.aggregate_SDD(mp_pdd)
sdd_iow = prepare_data.additional_sdd_merging(sdd_iow, how='outer')
sdd_iow = sdd_iow.merge(scor_iow, right_index=True, left_on='Sample', how='outer')
sdd_iow = sdd_iow.replace({'Sample': shortnames}).sort_values(by='Sample')

sdd_cau = pd.read_csv('../data/Metadata_CAU_sampling_log.csv', index_col=0).join(pd.read_csv('../data/GRADISTAT_CAU_vol_log-cau_closed.csv', index_col=0), how='outer')
sdd_cau = sdd_cau.merge(scor_cau, right_index=True, left_on='Sample', how='outer').reset_index()

## Additional variable generation (e.g. predictor derivatives)
 
# sdd_iow['Dist_WWTP_revsq'] = ((1/sdd_iow['Dist_WWTP'])**3)*10000000000  # calculates the squared of the reversed Distance 
# sdd_iow['Dist_WWTP_revsq'] = (((sdd_iow['Dist_WWTP'].max()-sdd_iow['Dist_WWTP'])+1)**3)/100000000000  # calculates the squared of the reversed Distance 
# sdd_iow['Dist_WWTP_revsq'] = ((sdd_iow['Dist_WWTP'].max()/sdd_iow['Dist_WWTP'])**3)/100  # calculates the squared of the reversed Distance
sdd_iow['Dist_WWTP_revsq'] = ((sdd_iow['Dist_WWTP'].max()/sdd_iow['Dist_WWTP'])**2)  # calculates the squared of the reversed Distance

## Split data into samples used for building the model and samples used for predicting.

model_data = sdd_iow.loc[~sdd_iow.Concentration.isna()].set_index('Sample')
pred_data = sdd_iow.loc[sdd_iow.Concentration.isna()]
pred_data = pd.concat([pred_data, sdd_cau.drop('Date',axis=1)]).set_index('Sample')

## Potential outlier exclusion
#model_data = model_data.drop(['S08','S10d','S05','S32'])

## List of features (predictors) to be used in the model. Beware: depending on the preprocessing steps not all features might be used.

featurelist = [
    'Depth',
    # 'LON', 'LAT',
    'Dist_Land',
    'Dist_Marina',
    'Dist_WWTP',
    'WWTP_influence_as_tracer_mean_dist',
    'WWTP_influence_as_cumulated_residence',
    # 'WWTP_influence_as_mean_time_travelled',
    # 'Dist_WWTP2',
    #'Dist_WWTP_revsq',
    # 'MODE 1 (µm)',
    # 'D10 (µm)',
    'D50 (µm)',
    # 'D90 (µm)',
    # 'perc GRAVEL',
    # 'perc SAND',
    'perc MUD',
    # 'perc CLAY',
    # 'OM_D50',
    'TOC',
    # 'Hg',
    # 'TIC',
    # 'regio_sep',
    'PC1', 'PC2'
    ]
model_X = model_data[featurelist]
model_y = model_data[target]
pred_X = pred_data[featurelist]

X_train, X_test, y_train, y_test = train_test_split(model_X, model_y, train_size=0.75, test_size=0.25)

# %%
from autosklearn.regression import AutoSklearnRegressor

# if file exists at "/tmp/autosklearn_resampling_example_tmp": delete it
from pathlib import Path
tmp_folder = Path("/tmp/autosklearn_resampling_example_tmp")
if tmp_folder.exists():
    import shutil
    shutil.rmtree(tmp_folder)

automl = AutoSklearnRegressor(
    time_left_for_this_task=24000,
    per_run_time_limit=600,
    tmp_folder="/tmp/autosklearn_resampling_example_tmp",
    disable_evaluator_output=False,
    n_jobs=-1,
    resampling_strategy="cv",
    resampling_strategy_arguments={"folds": 10},
)
automl.fit(X_train, y_train, dataset_name="Schlei_sediments")
# Out:
# AutoSklearnRegressor(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                      n_jobs=-1, per_run_time_limit=600,
#                      resampling_strategy='cv',
#                      resampling_strategy_arguments={'folds': 10},
#                      time_left_for_this_task=24000,
#                      tmp_folder='/tmp/autosklearn_resampling_example_tmp')

# %%
print("Before re-fit")
automl.refit(X_train, y_train)
predictions = automl.predict(X_test)
print("R2 score:", r2_score(y_test, predictions))
# Out:
# Before re-fit
# R2 score: -0.23227335636538582

# %%
print("After re-fit")
automl.refit(model_X.copy(), model_y.copy())
predictions_all = automl.predict(model_X)
print("R2 score:", r2_score(model_y, predictions_all))
# Out:
# After re-fit
# R2 score: 0.9554340735373072

# %%
print(automl.show_models())
# Out:
# {136: {'model_id': 136, 'rank': 1, 'cost': 33.7452815634619, 'ensemble_weight': 0.14, 'voting_model': VotingRegressor(estimators=None), 'estimators': [{'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66d5b6fd60>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66d5a6d370>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e9c29a0>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666ecf5160>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667a6c3760>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667a6c3d30>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=128,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f668808f5b0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66621c4100>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66621c42b0>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6667c8a550>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666627e3a0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666627ea60>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667aa890a0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667ad3d5b0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667ad3d550>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666c17c040>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6665643820>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6665643c10>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666eade3d0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66d4f91070>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66d4f91250>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66786cc070>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667947ba00>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667947b880>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=32,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66783399d0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667adf4160>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667adf45e0>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666f9fc310>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667a2a0b80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667a2a04c0>, 'sklearn_regressor': MLPRegressor(alpha=0.0015901429576245345, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(57, 57, 57),
#              learning_rate_init=0.030415503815134217, max_iter=64,
#              n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#              verbose=0, warm_start=True)}]}, 688: {'model_id': 688, 'rank': 2, 'cost': 34.54216516653416, 'ensemble_weight': 0.12, 'voting_model': VotingRegressor(estimators=None), 'estimators': [{'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66605889d0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66790242b0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666eb0fa30>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667822e310>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f665f90ed00>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666f46afa0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f668808f5e0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666df6f280>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e23f3a0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666ea287f0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66604e1b80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66887bdd60>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66654a23a0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666e10f700>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e10fa60>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667937d490>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6679336a30>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6679336af0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66604f7490>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666e88ad60>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e88a3a0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667947b1f0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6679362b20>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6679362d00>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667a97d4c0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666d698970>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666d6988e0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666cb5d070>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6678cef040>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66887058e0>, 'sklearn_regressor': ARDRegression(alpha_1=0.0009116711365393869, alpha_2=6.842761148008082e-09,
#               copy_X=False, lambda_1=8.926355724685869e-07,
#               lambda_2=2.023326961568302e-06,
#               threshold_lambda=36106.93947398286, tol=2.7026272071008506e-05)}]}, 2486: {'model_id': 2486, 'rank': 3, 'cost': 1.2363157209898665, 'ensemble_weight': 0.54, 'voting_model': VotingRegressor(estimators=None), 'estimators': [{'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66d5af2a60>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6666220490>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66792e4a60>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666029e610>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667a445eb0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6665a6e2b0>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666c8650a0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666c17c430>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f665f9d1040>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666fdc7b80>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f668831fd90>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666f578400>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=64, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666029e940>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6665a6ee80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66880e4490>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66887eca00>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6662d1a130>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667a4452b0>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=64, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667ae29b80>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66780907c0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667aad4b20>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6678c9be50>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666c17cd00>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6660cbb670>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f667ab48370>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666fc5b580>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6679a4b0d0>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666e554df0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66887479d0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666cf5d670>, 'sklearn_regressor': MLPRegressor(alpha=0.002792106079994542, beta_1=0.999, beta_2=0.9,
#              hidden_layer_sizes=(159,), learning_rate_init=0.013089134221621328,
#              max_iter=128, n_iter_no_change=32, random_state=1,
#              validation_fraction=0.0, verbose=0, warm_start=True)}]}, 3019: {'model_id': 3019, 'rank': 4, 'cost': 2.871434313064459, 'ensemble_weight': 0.2, 'voting_model': VotingRegressor(estimators=None), 'estimators': [{'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66d5de97c0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667a445280>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66d58be820>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1951.5390625, coef0=0.6740081503741637,
#     degree=5, epsilon=0.009985029958922344, gamma=0.008247897360529255,
#     kernel='poly', tol=0.00034356358898244584, verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66789f4fd0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6666264160>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666efe8b80>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1950.3697916666667,
#     coef0=0.6740081503741637, degree=5, epsilon=0.009985029958922344,
#     gamma=0.008247897360529255, kernel='poly', tol=0.00034356358898244584,
#     verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f666e792e20>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f665fe27580>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666dccffa0>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1949.8671875, coef0=0.6740081503741637,
#     degree=5, epsilon=0.009985029958922344, gamma=0.008247897360529255,
#     kernel='poly', tol=0.00034356358898244584, verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66674915b0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f66887bdc10>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e6df850>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1949.1875, coef0=0.6740081503741637,
#     degree=5, epsilon=0.009985029958922344, gamma=0.008247897360529255,
#     kernel='poly', tol=0.00034356358898244584, verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66790071c0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667ad8ff70>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f6678d44610>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1948.5182291666667,
#     coef0=0.6740081503741637, degree=5, epsilon=0.009985029958922344,
#     gamma=0.008247897360529255, kernel='poly', tol=0.00034356358898244584,
#     verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6678741df0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f6661c27460>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f66880cdac0>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1948.0026041666667,
#     coef0=0.6740081503741637, degree=5, epsilon=0.009985029958922344,
#     gamma=0.008247897360529255, kernel='poly', tol=0.00034356358898244584,
#     verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6678d27e50>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f667948ee80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f667a6db8e0>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1947.3151041666667,
#     coef0=0.6740081503741637, degree=5, epsilon=0.009985029958922344,
#     gamma=0.008247897360529255, kernel='poly', tol=0.00034356358898244584,
#     verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6688b042b0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666e9e5b80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666deb5040>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1946.6328125, coef0=0.6740081503741637,
#     degree=5, epsilon=0.009985029958922344, gamma=0.008247897360529255,
#     kernel='poly', tol=0.00034356358898244584, verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f66d56ea5e0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666fd661c0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666e5ced00>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1946.1171875, coef0=0.6740081503741637,
#     degree=5, epsilon=0.009985029958922344, gamma=0.008247897360529255,
#     kernel='poly', tol=0.00034356358898244584, verbose=0)}, {'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7f6688ab4910>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7f666f262820>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7f666efd9820>, 'sklearn_regressor': SVR(C=509.2266853161204, cache_size=1945.4322916666667,
#     coef0=0.6740081503741637, degree=5, epsilon=0.009985029958922344,
#     gamma=0.008247897360529255, kernel='poly', tol=0.00034356358898244584,
#     verbose=0)}]}}

# %%
# summarize
print(automl.sprint_statistics())
# evaluate best model
pd.DataFrame(automl.cv_results_)
# Out:
# auto-sklearn results:
#   Dataset name: Schlei_sediments
#   Metric: r2
#   Best validation score: -0.236316
#   Number of target algorithm runs: 3974
#   Number of successful target algorithm runs: 2055
#   Number of crashed target algorithm runs: 1890
#   Number of target algorithms that exceeded the time limit: 29
#   Number of target algorithms that exceeded the memory limit: 0
#       mean_test_score  rank_test_scores  mean_fit_time  \
# 0          -22.259696              2239      10.963022
# 1          -45.604559              2625       5.225044
# 2          -11.347622              2062       4.801776
# 3           -8.076222              2018       4.992872
# 4           -5.010014              1959       5.654037
# ...               ...               ...            ...
# 3969         0.000000                 1       0.761444
# 3970         0.000000                 1      28.098570
# 3971         0.000000                 1       2.643786
# 3972       -30.907470              2382       3.732392
# 3973     -5630.878038              3841       4.498592
#
#                                                  params   status  budgets  \
# 0     {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# 1     {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# 2     {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# 3     {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# 4     {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# ...                                                 ...      ...      ...
# 3969  {'data_preprocessor:__choice__': 'feature_type...    Crash      0.0
# 3970  {'data_preprocessor:__choice__': 'feature_type...  Timeout      0.0
# 3971  {'data_preprocessor:__choice__': 'feature_type...    Crash      0.0
# 3972  {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
# 3973  {'data_preprocessor:__choice__': 'feature_type...  Success      0.0
#
#      param_data_preprocessor:__choice__ param_feature_preprocessor:__choice__  \
# 0                          feature_type                      no_preprocessing
# 1                          feature_type                      no_preprocessing
# 2                          feature_type                            polynomial
# 3                          feature_type                            polynomial
# 4                          feature_type                            polynomial
# ...                                 ...                                   ...
# 3969                       feature_type               select_rates_regression
# 3970                       feature_type          select_percentile_regression
# 3971                       feature_type               select_rates_regression
# 3972                       feature_type                      no_preprocessing
# 3973                       feature_type    extra_trees_preproc_for_regression
#
#      param_regressor:__choice__  \
# 0                 random_forest
# 1              gaussian_process
# 2              gaussian_process
# 3              gaussian_process
# 4              gaussian_process
# ...                         ...
# 3969                        sgd
# 3970                 libsvm_svr
# 3971                        sgd
# 3972              liblinear_svr
# 3973                 libsvm_svr
#
#      param_data_preprocessor:feature_type:numerical_transformer:imputation:strategy  \
# 0                                                  mean
# 1                                                median
# 2                                         most_frequent
# 3                                         most_frequent
# 4                                         most_frequent
# ...                                                 ...
# 3969                                               mean
# 3970                                      most_frequent
# 3971                                      most_frequent
# 3972                                      most_frequent
# 3973                                             median
#
#       ... param_regressor:gradient_boosting:n_iter_no_change  \
# 0     ...                                                NaN
# 1     ...                                                NaN
# 2     ...                                                NaN
# 3     ...                                                NaN
# 4     ...                                                NaN
# ...   ...                                                ...
# 3969  ...                                                NaN
# 3970  ...                                                NaN
# 3971  ...                                                NaN
# 3972  ...                                                NaN
# 3973  ...                                                NaN
#
#      param_regressor:gradient_boosting:validation_fraction  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3969                                                NaN
# 3970                                                NaN
# 3971                                                NaN
# 3972                                                NaN
# 3973                                                NaN
#
#      param_regressor:libsvm_svr:coef0 param_regressor:libsvm_svr:degree  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 3969                              NaN                               NaN
# 3970                         0.277936                               4.0
# 3971                              NaN                               NaN
# 3972                              NaN                               NaN
# 3973                         0.529086                               5.0
#
#       param_regressor:libsvm_svr:gamma  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 3969                               NaN
# 3970                          0.016437
# 3971                               NaN
# 3972                               NaN
# 3973                          2.408886
#
#      param_regressor:mlp:validation_fraction  param_regressor:sgd:epsilon  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 3969                                     NaN                     0.055052
# 3970                                     NaN                          NaN
# 3971                                     NaN                     0.067388
# 3972                                     NaN                          NaN
# 3973                                     NaN                          NaN
#
#       param_regressor:sgd:eta0  param_regressor:sgd:l1_ratio  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 3969                  0.010000                           NaN
# 3970                       NaN                           NaN
# 3971                  0.005043                           NaN
# 3972                       NaN                           NaN
# 3973                       NaN                           NaN
#
#       param_regressor:sgd:power_t
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 3969                         0.25
# 3970                          NaN
# 3971                         0.25
# 3972                          NaN
# 3973                          NaN
#
# [3974 rows x 159 columns]

# %%
automl.leaderboard(detailed=True)
# Out:
#           rank  ensemble_weight            type       cost  duration  \
# model_id
# 2486         1             0.54             mlp   1.236316  5.000706
# 3019         2             0.20      libsvm_svr   2.871434  4.798249
# 136          3             0.14             mlp  33.745282  4.726459
# 688          4             0.12  ard_regression  34.542165  4.997399
#
#           config_id  train_loss  seed    start_time      end_time  budget  \
# model_id
# 2486           2485    0.016215     0  1.665244e+09  1.665244e+09     0.0
# 3019           3018    0.123338     0  1.665247e+09  1.665247e+09     0.0
# 136             135    0.277917     0  1.665231e+09  1.665231e+09     0.0
# 688             687    0.017737     0  1.665234e+09  1.665234e+09     0.0
#
#                       status data_preprocessors  \
# model_id
# 2486      StatusType.SUCCESS                 []
# 3019      StatusType.SUCCESS                 []
# 136       StatusType.SUCCESS                 []
# 688       StatusType.SUCCESS                 []
#
#                          feature_preprocessors balancing_strategy  \
# model_id
# 2486      [extra_trees_preproc_for_regression]               None
# 3019      [extra_trees_preproc_for_regression]               None
# 136                  [select_rates_regression]               None
# 688                               [polynomial]               None
#
#           config_origin
# model_id
# 2486      Random Search
# 3019      Random Search
# 136       Random Search
# 688       Random Search

# %%
from tpot import TPOTRegressor
from sklearn.model_selection import train_test_split

tpot = TPOTRegressor(generations=5, population_size=50, verbosity=2)
tpot.fit(X_train, y_train)

# %%
print(tpot.score(X_test, y_test))
preds = tpot.predict(X_test)
print(f'R²: {r2_score(y_test, preds)}')

tpot.export('../plots/tpot_pipeline.py')
